# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/Machine-School/blob/main/Handeling_Null_Values.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

primary_dataset = pd.read_excel('/content/drive/MyDrive/Machine Learning Models/HMC_SleepStage_2022.11.28.xlsx')

# %%
dataset = primary_dataset.loc[:,primary_dataset.columns != "Subject"]
dataset = dataset.loc[:,dataset.columns != "Epoch"]

# %%
columns_name = list(dataset.columns)
columns_name.remove("Sleep_Stage")

# %%
type(dataset["DTR"][97285])
# Out:
# numpy.float64

# %%
for i in columns_name:
  for j in range(108451):
    if str(dataset[i][j]) == "nan":
      print(i,j)
      break
# Out:
# RelativePower_Delta_C4 954
# DAR 954
# DTR 954
# DTABR 954
# RelativePower_Delta 954

# %%
dataset.head()
# Out:
#   Sleep_Stage  MeanP_Alpha_F4  MedianF_Alpha_F4  MeanF_Alpha_F4  \
# 0          N1         0.00034          10.11512        17.85756
# 1          N1         0.00035          10.73951        17.60780
# 2          N1         0.00035           9.36585        17.60780
# 3          N1         0.00054           9.74049        15.98439
# 4          N1         0.00034          10.11512        16.48390
#
#    SpectralEdge_Alpha_F4  PeakF_Alpha_F4  MeanP_Beta_F4  MedianF_Beta_F4  \
# 0               17.48293        10.24000        0.00047         17.73268
# 1               17.10829         9.11610        0.00048         16.85854
# 2               16.98341         9.24098        0.00042         17.35805
# 3               15.48488         8.36683        0.00051         14.61073
# 4               15.98439        12.23805        0.00034         15.11024
#
#    MeanF_Beta_F4  SpectralEdge_Beta_F4  ...  RelativePower_Delta_O2  \
# 0       25.35024              27.47317  ...                0.555528
# ...

# %%
dataset.isnull()
# Out:
#         Sleep_Stage  MeanP_Alpha_F4  MedianF_Alpha_F4  MeanF_Alpha_F4  \
# 0             False           False             False           False
# 1             False           False             False           False
# 2             False           False             False           False
# 3             False           False             False           False
# 4             False           False             False           False
# ...             ...             ...               ...             ...
# 108446        False           False             False           False
# 108447        False           False             False           False
# 108448        False           False             False           False
# 108449        False           False             False           False
# 108450        False           False             False           False
#
#         SpectralEdge_Alpha_F4  PeakF_Alpha_F4  MeanP_Beta_F4  MedianF_Beta_F4  \
# ...

# %%
dataset.fillna(6)
# Out:
#        Sleep_Stage  MeanP_Alpha_F4  MedianF_Alpha_F4  MeanF_Alpha_F4  \
# 0               N1         0.00034          10.11512        17.85756
# 1               N1         0.00035          10.73951        17.60780
# 2               N1         0.00035           9.36585        17.60780
# 3               N1         0.00054           9.74049        15.98439
# 4               N1         0.00034          10.11512        16.48390
# ...            ...             ...               ...             ...
# 108446           W         0.00042           9.99024        17.10829
# 108447           W         0.00033          10.48976        16.60878
# 108448           W         0.00064          10.48976        18.73171
# 108449           W         0.00051          10.11512        17.85756
# 108450           W         0.00128          10.61463        21.47902
#
#         SpectralEdge_Alpha_F4  PeakF_Alpha_F4  MeanP_Beta_F4  MedianF_Beta_F4  \
# ...
