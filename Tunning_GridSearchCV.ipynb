# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/Machine-School/blob/main/Tunning_GridSearchCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data  = pd.read_csv("https://raw.githubusercontent.com/RafsanJany-44/Machine-School/main/datasets/EEG_HMC_Wake_NREM_REM_3000.csv")

# %%
data.head()
# Out:
#   Sleep Stage  MeanP_Alpha_F4  MedianF_Alpha_F4  MeanF_Alpha_F4  \
# 0        Wake         0.00051           8.74146        18.48195
# 1        Wake         0.00040          10.24000        17.48293
# 2        Wake         0.00036           9.74049        17.98244
# 3        Wake         0.00035          10.11512        17.60780
# 4        Wake         0.00033           9.74049        17.60780
#
#    Spectral Edge_Alpha_F4  PeakF_Alpha_F4  MeanP_Beta_F4  MedianF_Beta_F4  \
# 0                17.48293         8.24195        0.00071         19.73073
# 1                16.85854        10.61463        0.00051         17.23317
# 2                17.48293         8.74146        0.00047         17.60780
# 3                17.10829         9.61561        0.00047         17.35805
# 4                17.23317         8.11707        0.00043         17.23317
#
#    MeanF_Beta_F4  Spectral Edge_Beta_F4  ...  MeanP_Delta_O2  \
# 0       29.84585               33.84195  ...         0.00724
# 1       26.34927               29.34634  ...         0.00723
# 2       25.47512               28.22244  ...         0.00230
# 3       26.47415               28.72195  ...         0.00091
# 4       25.84976               28.09756  ...         0.00175
#
#    MedianF_Delta_O2  MeanF_Delta_O2  Spectral Edge_Delta_O2  PeakF_Delta_O2  \
# 0           0.74927         3.87122                 1.99805         0.87415
# 1           0.49951         3.74634                 1.24878         0.49951
# 2           0.62439         5.24488                 2.12293         0.62439
# 3           0.87415         6.61854                 3.12195         0.62439
# 4           0.49951         5.74439                 2.24780         0.49951
#
#    MeanP_Gamma_O2  MedianF_Gamma_O2  MeanF_Gamma_O2  Spectral Edge_Gamma_O2  \
# 0        0.000210          35.21561        42.20878                49.95122
# 1        0.000095          34.34146        43.33268                49.95122
# 2        0.000074          34.59122        45.95512                49.95122
# 3        0.000082          32.46829        43.95707                49.95122
# 4        0.000077          33.59220        44.83122                49.95122
#
#    PeakF_Gamma_O2
# 0        49.95122
# 1        49.95122
# 2        49.95122
# 3        49.95122
# 4        49.95122
#
# [5 rows x 76 columns]

# %%
X = data.loc[:, data.columns != "Sleep Stage"]
y = data["Sleep Stage"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()

# %% [markdown]
# #Dictionary  of hyperparameter values to search

# %%
search_space = {
    'n_estimators' : [100,200,500],
    'max_depth' : [3,6,9]
}

# %%
import sklearn.metrics as k
print(*k.get_scorer_names(),sep='\n')
# Out:
# accuracy
# adjusted_mutual_info_score
# adjusted_rand_score
# average_precision
# balanced_accuracy
# completeness_score
# explained_variance
# f1
# f1_macro
# f1_micro
# f1_samples
# f1_weighted
# fowlkes_mallows_score
# homogeneity_score
# jaccard
# jaccard_macro
# jaccard_micro
# jaccard_samples
# jaccard_weighted
# matthews_corrcoef
# max_error
# mutual_info_score
# neg_brier_score
# neg_log_loss
# neg_mean_absolute_error
# neg_mean_absolute_percentage_error
# neg_mean_gamma_deviance
# neg_mean_poisson_deviance
# neg_mean_squared_error
# neg_mean_squared_log_error
# neg_median_absolute_error
# neg_negative_likelihood_ratio
# neg_root_mean_squared_error
# normalized_mutual_info_score
# positive_likelihood_ratio
# precision
# precision_macro
# precision_micro
# precision_samples
# precision_weighted
# r2
# rand_score
# recall
# recall_macro
# recall_micro
# recall_samples
# recall_weighted
# roc_auc
# roc_auc_ovo
# roc_auc_ovo_weighted
# roc_auc_ovr
# roc_auc_ovr_weighted
# top_k_accuracy
# v_measure_score

# %%
from sklearn.model_selection import GridSearchCV

gs = GridSearchCV(estimator = rfc,
                  param_grid = search_space,
                  scoring=['r2','neg_mean_squared_error'],
                  refit = 'r2',
                  cv = 5,
                  verbose =4)

# %%
gs.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 911, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 442, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# [CV 1/5] END max_depth=3, n_estimators=100; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.4s
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 911, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'REM'
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 442, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'REM'
#
#   warnings.warn(
# [CV 2/5] END max_depth=3, n_estimators=100; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.4s
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 911, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 442, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# [CV 3/5] END max_depth=3, n_estimators=100; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.4s
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 911, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 442, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# [CV 4/5] END max_depth=3, n_estimators=100; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.4s
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 911, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 442, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# [CV 5/5] END max_depth=3, n_estimators=100; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.4s
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 911, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 442, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# [CV 1/5] END max_depth=3, n_estimators=200; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.7s
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 911, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'REM'
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 442, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'REM'
#
#   warnings.warn(
# [CV 2/5] END max_depth=3, n_estimators=200; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.8s
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 911, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 442, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# [CV 3/5] END max_depth=3, n_estimators=200; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.8s
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 911, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 442, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# [CV 4/5] END max_depth=3, n_estimators=200; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.7s
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 911, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 442, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# [CV 5/5] END max_depth=3, n_estimators=200; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   1.0s
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 911, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 442, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# [CV 1/5] END max_depth=3, n_estimators=500; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   2.4s
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 911, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'REM'
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 442, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'REM'
#
#   warnings.warn(
# [CV 2/5] END max_depth=3, n_estimators=500; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   1.9s
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 911, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 442, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# [CV 3/5] END max_depth=3, n_estimators=500; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   2.0s
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 911, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 442, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# [CV 4/5] END max_depth=3, n_estimators=500; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   2.1s
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 911, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 442, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# [CV 5/5] END max_depth=3, n_estimators=500; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   1.9s
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 911, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
# ...
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# [CV 5/5] END max_depth=9, n_estimators=200; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   1.4s
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 911, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 442, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# [CV 1/5] END max_depth=9, n_estimators=500; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   3.5s
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 911, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'REM'
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 442, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'REM'
#
#   warnings.warn(
# [CV 2/5] END max_depth=9, n_estimators=500; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   3.8s
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 911, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 442, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# [CV 3/5] END max_depth=9, n_estimators=500; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   3.3s
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 911, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 442, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# [CV 4/5] END max_depth=9, n_estimators=500; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   3.3s
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 911, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 442, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/series.py", line 893, in __array__
#     return np.asarray(self._values, dtype)
# ValueError: could not convert string to float: 'NREM'
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:952: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# [CV 5/5] END max_depth=9, n_estimators=500; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   3.9s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [3, 6, 9],
#                          'n_estimators': [100, 200, 500]},
#              refit='r2', scoring=['r2', 'neg_mean_squared_error'], verbose=4)

# %%
print(gs.best_estimator_)
# Out:
# RandomForestClassifier(max_depth=3)

# %%
print(gs.best_params_)
# Out:
# {'max_depth': 3, 'n_estimators': 100}

# %%
print(gs.best_score_)
# Out:
# nan

# %%
df = pd.DataFrame(gs.cv_results_)
df = df.sort_values("rank_test_r2")
df.to_csv("hello.csv",index = False)
